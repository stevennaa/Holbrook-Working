# %% [markdown]
# ## Set Up

# %%
#!pip install -r requirements.txt

# %%
# %pip install python-gnupg
# %pip install eep153_tools
# Out:
# Requirement already satisfied: python-gnupg in /srv/conda/lib/python3.9/site-packages (0.5.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: eep153_tools in /srv/conda/lib/python3.9/site-packages (0.12.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import cfe.regression as rgsn
from eep153_tools.sheets import read_sheets

# %% [markdown]
# ## Data Loading

# %%
InputFiles = {'Expenditures':('1yVLriVpo7KGUXvR3hq_n53XpXlD5NmLaH1oOMZyV0gQ','Expenditures (2019-20)'),
              'Prices':('1yVLriVpo7KGUXvR3hq_n53XpXlD5NmLaH1oOMZyV0gQ','Prices'),
              'HH Characteristics':('1yVLriVpo7KGUXvR3hq_n53XpXlD5NmLaH1oOMZyV0gQ','HH Characteristics'),
              'FCT':('1yVLriVpo7KGUXvR3hq_n53XpXlD5NmLaH1oOMZyV0gQ','FCT'),
              'RDI':('1yVLriVpo7KGUXvR3hq_n53XpXlD5NmLaH1oOMZyV0gQ','RDI'),}

# %%
# Get Expenditure data (2019-20)
x = read_sheets(InputFiles['Expenditures'][0], sheet=InputFiles['Expenditures'][1])
x.columns.name = 'j'
# x may have duplicate columns
x = x.T.groupby('j').sum().T
x = x.replace(0,np.nan) # Replace zeros with missing
# Take logs of expenditures; call this y
y = np.log(x.set_index(['i','t','m']))
#get hh household data
d = read_sheets(InputFiles['HH Characteristics'][0], sheet=InputFiles['HH Characteristics'][1])
d.columns.name = 'k'
d.set_index(['i','t','m'],inplace=True)
d['children_0413_size']=np.sum(d[['F 04-08', 'F 09-13', 'M 04-08', 'M 09-13']], axis=1)
####Aviod Multicollinearity
d=d.drop(['F 04-08', 'F 09-13', 'M 04-08', 'M 09-13'], axis=1)

# Get prices
p = read_sheets(InputFiles['Prices'][0],
                sheet=InputFiles['Prices'][1])
p = p.set_index(['t','m'])
p.columns.name = 'j'
p = p.xs('2019-20',level='t')
p = p.apply(lambda x: pd.to_numeric(x,errors='coerce'))
p = p.replace(0,np.nan)



fct = read_sheets(InputFiles['FCT'][0],
                  sheet=InputFiles['FCT'][1])

fct = fct.set_index('j')
fct.columns.name = 'n'

fct = fct.apply(lambda x: pd.to_numeric(x,errors='coerce'))

################## RDI, if available (consider using US) #####################
rdi = read_sheets(InputFiles['RDI'][0],
                  sheet=InputFiles['RDI'][1])
rdi = rdi.set_index('n')
rdi.columns.name = 'k'
# Out:
# /tmp/ipykernel_217/2175215701.py:6: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   x = x.replace(0,np.nan) # Replace zeros with missing

# %%
x.head()
# Out:
# j   Beans    Beef     Beer  Biscuits  Bongo  Bread  Butter, etc.  Cabbages  \
# 0  3600.0     NaN      NaN       NaN    NaN    NaN           NaN    1400.0
# 1     NaN     NaN      NaN       NaN    NaN  500.0           NaN       NaN
# 2  1000.0  4500.0      NaN       NaN    NaN    NaN           NaN       NaN
# 3  2800.0     NaN      NaN       NaN    NaN    NaN           NaN       NaN
# 4     NaN     NaN  17500.0       NaN    NaN    NaN           NaN       NaN
#
# j  Cake  Cassava  ...    Tea  Tomatoes  Waragi  Water  Wheat (flour)     Yam  \
# 0   NaN   6000.0  ...  200.0    1000.0     NaN    NaN            NaN  3000.0
# 1   NaN      NaN  ...    NaN       NaN     NaN    NaN            NaN     NaN
# 2   NaN   4000.0  ...    NaN     800.0     NaN    NaN            NaN     NaN
# 3   NaN   3200.0  ...  200.0     500.0     NaN    NaN            NaN     NaN
# 4   NaN   4000.0  ...  400.0    2100.0     NaN    NaN            NaN     NaN
#
# j  Yogurt                                 i        m        t
# 0     NaN  00c9353d8ebe42faabf5919b81d7fae7  Eastern  2019-20
# 1     NaN  062da72d5d3a457e9336b62c8bb9096d  Eastern  2019-20
# 2     NaN  0d0e29faff394154a69562b4527b48b8  Eastern  2019-20
# 3     NaN  0e03e253c35d4333a1ffad2df9d38850  Eastern  2019-20
# 4     NaN                        1013000201  Central  2019-20
#
# [5 rows x 77 columns]

# %%
y.head()
# Out:
# j                                                    Beans      Beef  \
# i                                t       m
# 00c9353d8ebe42faabf5919b81d7fae7 2019-20 Eastern  8.188689       NaN
# 062da72d5d3a457e9336b62c8bb9096d 2019-20 Eastern       NaN       NaN
# 0d0e29faff394154a69562b4527b48b8 2019-20 Eastern  6.907755  8.411833
# 0e03e253c35d4333a1ffad2df9d38850 2019-20 Eastern  7.937375       NaN
# 1013000201                       2019-20 Central       NaN       NaN
#
# j                                                     Beer  Biscuits  Bongo  \
# i                                t       m
# 00c9353d8ebe42faabf5919b81d7fae7 2019-20 Eastern       NaN       NaN    NaN
# 062da72d5d3a457e9336b62c8bb9096d 2019-20 Eastern       NaN       NaN    NaN
# 0d0e29faff394154a69562b4527b48b8 2019-20 Eastern       NaN       NaN    NaN
# 0e03e253c35d4333a1ffad2df9d38850 2019-20 Eastern       NaN       NaN    NaN
# 1013000201                       2019-20 Central  9.769956       NaN    NaN
#
# j                                                    Bread  Butter, etc.  \
# i                                t       m
# 00c9353d8ebe42faabf5919b81d7fae7 2019-20 Eastern       NaN           NaN
# 062da72d5d3a457e9336b62c8bb9096d 2019-20 Eastern  6.214608           NaN
# 0d0e29faff394154a69562b4527b48b8 2019-20 Eastern       NaN           NaN
# 0e03e253c35d4333a1ffad2df9d38850 2019-20 Eastern       NaN           NaN
# 1013000201                       2019-20 Central       NaN           NaN
#
# j                                                 Cabbages  Cake   Cassava  \
# i                                t       m
# 00c9353d8ebe42faabf5919b81d7fae7 2019-20 Eastern  7.244228   NaN  8.699515
# 062da72d5d3a457e9336b62c8bb9096d 2019-20 Eastern       NaN   NaN       NaN
# 0d0e29faff394154a69562b4527b48b8 2019-20 Eastern       NaN   NaN  8.294050
# 0e03e253c35d4333a1ffad2df9d38850 2019-20 Eastern       NaN   NaN  8.070906
# 1013000201                       2019-20 Central       NaN   NaN  8.294050
#
# j                                                 ...  Sugarcane  \
# i                                t       m        ...
# 00c9353d8ebe42faabf5919b81d7fae7 2019-20 Eastern  ...        NaN
# 062da72d5d3a457e9336b62c8bb9096d 2019-20 Eastern  ...        NaN
# 0d0e29faff394154a69562b4527b48b8 2019-20 Eastern  ...        NaN
# 0e03e253c35d4333a1ffad2df9d38850 2019-20 Eastern  ...        NaN
# 1013000201                       2019-20 Central  ...        NaN
#
# j                                                 Sweet Bananas  \
# i                                t       m
# 00c9353d8ebe42faabf5919b81d7fae7 2019-20 Eastern            NaN
# 062da72d5d3a457e9336b62c8bb9096d 2019-20 Eastern            NaN
# 0d0e29faff394154a69562b4527b48b8 2019-20 Eastern            NaN
# 0e03e253c35d4333a1ffad2df9d38850 2019-20 Eastern            NaN
# 1013000201                       2019-20 Central       7.600902
#
# j                                                 Sweet Potatoes       Tea  \
# i                                t       m
# 00c9353d8ebe42faabf5919b81d7fae7 2019-20 Eastern        8.294050  5.298317
# 062da72d5d3a457e9336b62c8bb9096d 2019-20 Eastern             NaN       NaN
# 0d0e29faff394154a69562b4527b48b8 2019-20 Eastern             NaN       NaN
# 0e03e253c35d4333a1ffad2df9d38850 2019-20 Eastern        8.517193  5.298317
# 1013000201                       2019-20 Central             NaN  5.991465
#
# j                                                 Tomatoes  Waragi  Water  \
# i                                t       m
# 00c9353d8ebe42faabf5919b81d7fae7 2019-20 Eastern  6.907755     NaN    NaN
# 062da72d5d3a457e9336b62c8bb9096d 2019-20 Eastern       NaN     NaN    NaN
# 0d0e29faff394154a69562b4527b48b8 2019-20 Eastern  6.684612     NaN    NaN
# 0e03e253c35d4333a1ffad2df9d38850 2019-20 Eastern  6.214608     NaN    NaN
# 1013000201                       2019-20 Central  7.649693     NaN    NaN
#
# j                                                 Wheat (flour)       Yam  \
# i                                t       m
# 00c9353d8ebe42faabf5919b81d7fae7 2019-20 Eastern            NaN  8.006368
# 062da72d5d3a457e9336b62c8bb9096d 2019-20 Eastern            NaN       NaN
# 0d0e29faff394154a69562b4527b48b8 2019-20 Eastern            NaN       NaN
# 0e03e253c35d4333a1ffad2df9d38850 2019-20 Eastern            NaN       NaN
# 1013000201                       2019-20 Central            NaN       NaN
#
# j                                                 Yogurt
# i                                t       m
# 00c9353d8ebe42faabf5919b81d7fae7 2019-20 Eastern     NaN
# 062da72d5d3a457e9336b62c8bb9096d 2019-20 Eastern     NaN
# 0d0e29faff394154a69562b4527b48b8 2019-20 Eastern     NaN
# 0e03e253c35d4333a1ffad2df9d38850 2019-20 Eastern     NaN
# 1013000201                       2019-20 Central     NaN
#
# [5 rows x 74 columns]

# %%
d.head()
# Out:
# k                                                 F 00-03  F 14-18  F 19-30  \
# i                                t       m
# 00c9353d8ebe42faabf5919b81d7fae7 2018-19              1.0      3.0      1.0
#                                  2019-20 Eastern      1.0      3.0      1.0
# 02dd448165ce46279ca601a02865d543 2018-19              0.0      0.0      1.0
# 037866653c7c4cb99a80f05a38cdafb2 2018-19              0.0      0.0      0.0
# 039a11571b874a88b7a6c200469fe4f3 2018-19              0.0      0.0      0.0
#
# k                                                 F 31-50  F 51+  M 00-03  \
# i                                t       m
# 00c9353d8ebe42faabf5919b81d7fae7 2018-19              0.0    1.0      0.0
#                                  2019-20 Eastern      0.0    1.0      0.0
# 02dd448165ce46279ca601a02865d543 2018-19              0.0    0.0      0.0
# 037866653c7c4cb99a80f05a38cdafb2 2018-19              1.0    0.0      0.0
# 039a11571b874a88b7a6c200469fe4f3 2018-19              1.0    0.0      0.0
#
# k                                                 M 14-18  M 19-30  M 31-50  \
# i                                t       m
# 00c9353d8ebe42faabf5919b81d7fae7 2018-19              0.0      0.0      0.0
#                                  2019-20 Eastern      0.0      0.0      0.0
# 02dd448165ce46279ca601a02865d543 2018-19              0.0      0.0      0.0
# 037866653c7c4cb99a80f05a38cdafb2 2018-19              0.0      0.0      0.0
# 039a11571b874a88b7a6c200469fe4f3 2018-19              0.0      0.0      1.0
#
# k                                                 M 51+  log HSize  \
# i                                t       m
# 00c9353d8ebe42faabf5919b81d7fae7 2018-19            0.0   2.079442
#                                  2019-20 Eastern    0.0   1.945910
# 02dd448165ce46279ca601a02865d543 2018-19            0.0   0.000000
# 037866653c7c4cb99a80f05a38cdafb2 2018-19            1.0   1.609438
# 039a11571b874a88b7a6c200469fe4f3 2018-19            0.0   1.609438
#
# k                                                 children_0413_size
# i                                t       m
# 00c9353d8ebe42faabf5919b81d7fae7 2018-19                         2.0
#                                  2019-20 Eastern                 1.0
# 02dd448165ce46279ca601a02865d543 2018-19                         0.0
# 037866653c7c4cb99a80f05a38cdafb2 2018-19                         3.0
# 039a11571b874a88b7a6c200469fe4f3 2018-19                         3.0

# %%
p.head()
# Out:
# j               Beans   Beef         Beer  Biscuits   Bongo   Bread  \
# m
# Central   2500.000000  12000  6000.000000    5000.0  1000.0  4500.0
# Eastern   2275.000000  10000  6785.714286    2000.0  1000.0  4500.0
# Northern  8833.333333  10000  6500.000000    2000.0  1000.0  5000.0
# Western   2200.000000  10000  5000.000000    2000.0  1250.0  4500.0
#
# j         Butter, etc.     Cabbages         Cake      Cassava  ...  \
# m                                                              ...
# Central        10000.0  2683.028286  1750.000000  1400.000000  ...
# Eastern        10000.0  1679.389313  1679.389313  1235.294118  ...
# Northern           NaN  2683.028286  1679.389313   890.196078  ...
# Western         6250.0  2351.145038  2683.028286  1125.000000  ...
#
# j           Sugarcane  Sweet Bananas  Sweet Potatoes          Tea    Tomatoes  \
# m
# Central   1679.389313    1169.607843     1550.000000  13000.00000  671.755725
# Eastern   1428.571429    1225.000000      794.444444  10000.00000  625.000000
# Northern   714.285714    1398.039216     1000.000000  10000.00000  625.000000
# Western   1341.514143    1720.588235      735.294118  11666.66667  750.000000
#
# j         Waragi   Water  Wheat (flour)          Yam  Yogurt
# m
# Central   8000.0  1000.0         2875.0  3358.778626  5000.0
# Eastern   6000.0  1600.0         2500.0  3465.103599  7200.0
# Northern  4000.0  2000.0         3000.0  5366.056572  7000.0
# Western   6000.0  2000.0         3200.0  5038.167939  8600.0
#
# [4 rows x 74 columns]

# %%
fct.head()
# Out:
# n               Energy  Protein  Fiber  Folate  Calcium  Carbohydrate  Iron  \
# j
# Avocado           1600     20.0   70.0     810      120          85.0   6.0
# Beans (dry)       1700     98.0   60.0     500      580         325.0  30.0
# Beans (fresh)     3470    214.0  160.0    5250     1130         626.0  51.0
# Beef              2510    182.0    0.0      60       70           0.0  19.0
# Beef (roasted)    2910    264.0    0.0      70       90           0.0  27.0
#
# n               Niacin  Riboflavin  Thiamin  Vitamin A  Vitamin B-12  \
# j
# Avocado          17.38        1.30     0.67         70           0.0
# Beans (dry)       7.00        1.20     3.40          0           0.0
# Beans (fresh)    11.74        2.12     7.13          0           0.0
# Beef             31.50        1.60     0.90          0          28.9
# Beef (roasted)   37.20        2.20     0.90          0          24.7
#
# n               Vitamin B-6  Vitamin C  Zinc
# j
# Avocado                2.57        100   6.0
# Beans (dry)            2.15         10   8.0
# Beans (fresh)          4.74         63  23.0
# Beef                   3.80          0  37.0
# Beef (roasted)         3.40          0  60.0

# %%
rdi.head()
# Out:
# k        F 00-03  M 00-03  F 04-08  M 04-08  F 09-13  M 09-13  F 14-18  \
# n
# Energy    1000.0   1000.0   1200.0   1400.0   1600.0   1800.0   1800.0
# Protein     13.0     13.0     19.0     19.0     34.0     34.0     46.0
# Fiber       14.0     14.0     16.8     19.6     22.4     25.2     25.2
# Folate     150.0    150.0    200.0    200.0    300.0    300.0    400.0
# Calcium    700.0    700.0   1000.0   1000.0   1300.0   1300.0   1300.0
#
# k        M 14-18  F 19-30  M 19-30  F 31-50  M 31-50   F 51+   M 51+
# n
# Energy    2200.0   2000.0   2400.0   1800.0   2200.0  1600.0  2000.0
# Protein     52.0     46.0     56.0     46.0     56.0    46.0    56.0
# Fiber       30.8     28.0     33.6     25.2     30.8    22.4    28.0
# Folate     400.0    400.0    400.0    400.0    400.0   400.0   400.0
# Calcium   1300.0   1000.0   1000.0   1000.0   1000.0  1200.0  1000.0

# %% [markdown]
# ## Demand System

# %%
y = y.stack()

d = d.stack()

# Check that indices are in right places!
assert y.index.names == ['i','t','m','j']
assert d.index.names == ['i','t','m','k']

# %%
from cfe import Regression

result = Regression(y=y,d=d)

# %%
ax = result.graph_beta()

# %%
import matplotlib.pyplot as plt
# Gamma is the coefficients of our regression of sub-equation
gamma_df = result.get_gamma()
# Create a bar chart for food elasticities of different population groups
def plot_gamma_table(gamma_table, population_group):
    """
    Ths function is designed to help create a bar chart displaying food expenditure changes with variations of household composition.

    Parameters:
    - gamma_table (DataFrame): The gamma table above.
    - population_group (string): Any population group (string) from the header of gamma table

    Returns:
    - A bar chart described above.
    
    """
    fig, ax = plt.subplots(figsize=(10, 6))
    ax.bar(gamma_table.index, gamma_table[population_group], color='green')
    ax.set_title(f'Population Group [{population_group}] and Its Household Food Expenditures Changes in Uganda')
    ax.set_xlabel('Foods')
    ax.set_ylabel('Change in Food Expenditures')
    plt.xticks(rotation=90, fontsize=5)
    plt.show()

print("Please choose from the following:\n'F 00-03', 'F 14-18', 'F 19-30', 'F 31-50', 'F 51+', 'M 00-03', 'M 14-18', 'M 19-30', 'M 31-50', 'M 51+', 'log HSize', 'children_0413_size'")
print("\n")  
population_input = input('Please input the population group you would like to visualize (No quotation mark required): ')
plot_gamma_table(gamma_df, population_input)
# Out:
# Please choose from the following:
# 'F 00-03', 'F 14-18', 'F 19-30', 'F 31-50', 'F 51+', 'M 00-03', 'M 14-18', 'M 19-30', 'M 31-50', 'M 51+', 'log HSize', 'children_0413_size'
# Please input the population group you would like to visualize (No quotation mark required):  F 31-50

# %% [markdown]
# This plot helps us to decide the food in school meal box in our policy analysis.

# %%
result.to_pickle('uganda_estimates.rgsn')

# %% [markdown]
# #### Budge and Demand

# %%
# Reference prices chosen from a particular time; average across place.
# These are prices per kilogram:
pbar = p.mean()
pbar = pbar[result.beta.index] # Only use prices for goods we can estimate

xhat = result.predicted_expenditures()

# Total food expenditures per household
xbar = xhat.groupby(['i','t','m']).sum()

# Reference budget
xref = xbar.quantile(0.5)  # Household at 0.5 quantile is median

qhat = (xhat.unstack('j')/pbar).dropna(how='all')

# Drop missing columns
qhat = qhat.loc[:,qhat.count()>0]

qhat.head()
# Out:
# j                                                    Beans      Beef  \
# i                                t       m
# 00c9353d8ebe42faabf5919b81d7fae7 2019-20 Eastern  0.966109  0.954852
# 0d0e29faff394154a69562b4527b48b8 2019-20 Eastern  0.607214  0.672272
# 0e03e253c35d4333a1ffad2df9d38850 2019-20 Eastern  0.697274  0.645229
# 1013000201                       2019-20 Central  1.082217  1.593470
# 1013000202                       2019-20 Central  0.811566  0.646910
#
# j                                                 Biscuits     Bread  \
# i                                t       m
# 00c9353d8ebe42faabf5919b81d7fae7 2019-20 Eastern  0.529135  0.850798
# 0d0e29faff394154a69562b4527b48b8 2019-20 Eastern  0.238071  0.546072
# 0e03e253c35d4333a1ffad2df9d38850 2019-20 Eastern  0.126015  0.514873
# 1013000201                       2019-20 Central  0.940559  1.571084
# 1013000202                       2019-20 Central  0.136108  0.363580
#
# j                                                 Cabbages   Cassava  \
# i                                t       m
# 00c9353d8ebe42faabf5919b81d7fae7 2019-20 Eastern  0.535620  6.901113
# 0d0e29faff394154a69562b4527b48b8 2019-20 Eastern  0.345704  4.371435
# 0e03e253c35d4333a1ffad2df9d38850 2019-20 Eastern  0.336834  5.557920
# 1013000201                       2019-20 Central  0.603654  3.091278
# 1013000202                       2019-20 Central  0.269303  3.188751
#
# j                                                  Chapati  Cooking Oil  \
# i                                t       m
# 00c9353d8ebe42faabf5919b81d7fae7 2019-20 Eastern  1.470342     0.911783
# 0d0e29faff394154a69562b4527b48b8 2019-20 Eastern  0.946336     0.593078
# 0e03e253c35d4333a1ffad2df9d38850 2019-20 Eastern  0.821073     0.572348
# 1013000201                       2019-20 Central  2.443312     0.809574
# 1013000202                       2019-20 Central  0.590778     0.388112
#
# j                                                     Dodo      Eggs  ...  \
# i                                t       m                            ...
# 00c9353d8ebe42faabf5919b81d7fae7 2019-20 Eastern  2.226708  1.392850  ...
# 0d0e29faff394154a69562b4527b48b8 2019-20 Eastern  1.219667  1.161810  ...
# 0e03e253c35d4333a1ffad2df9d38850 2019-20 Eastern  1.289756  1.021713  ...
# 1013000201                       2019-20 Central  2.690171  1.965417  ...
# 1013000202                       2019-20 Central  1.328123  1.024650  ...
#
# j                                                     Rice      Salt  \
# i                                t       m
# 00c9353d8ebe42faabf5919b81d7fae7 2019-20 Eastern  2.129935  0.207750
# 0d0e29faff394154a69562b4527b48b8 2019-20 Eastern  1.078110  0.158210
# 0e03e253c35d4333a1ffad2df9d38850 2019-20 Eastern  1.061960  0.170171
# 1013000201                       2019-20 Central  1.732506  0.146772
# 1013000202                       2019-20 Central  0.649729  0.163583
#
# j                                                  Sim Sim      Soda  \
# i                                t       m
# 00c9353d8ebe42faabf5919b81d7fae7 2019-20 Eastern  0.207190  0.885284
# 0d0e29faff394154a69562b4527b48b8 2019-20 Eastern  0.162620  0.721722
# 0e03e253c35d4333a1ffad2df9d38850 2019-20 Eastern  0.132416  0.563035
# 1013000201                       2019-20 Central  0.264052  2.164785
# 1013000202                       2019-20 Central  0.074458  0.426173
#
# j                                                  Sorghum  Sweet Bananas  \
# i                                t       m
# 00c9353d8ebe42faabf5919b81d7fae7 2019-20 Eastern  1.349937       1.701003
# 0d0e29faff394154a69562b4527b48b8 2019-20 Eastern  0.709172       1.487601
# 0e03e253c35d4333a1ffad2df9d38850 2019-20 Eastern  0.693901       1.132104
# 1013000201                       2019-20 Central  1.392542       3.016939
# 1013000202                       2019-20 Central  0.326961       0.890652
#
# j                                                 Sweet Potatoes       Tea  \
# i                                t       m
# 00c9353d8ebe42faabf5919b81d7fae7 2019-20 Eastern       10.470627  0.020685
# 0d0e29faff394154a69562b4527b48b8 2019-20 Eastern        4.812544  0.013243
# 0e03e253c35d4333a1ffad2df9d38850 2019-20 Eastern        5.371800  0.012889
# 1013000201                       2019-20 Central        5.353990  0.033047
# 1013000202                       2019-20 Central        3.515201  0.013046
#
# j                                                 Tomatoes    Waragi
# i                                t       m
# 00c9353d8ebe42faabf5919b81d7fae7 2019-20 Eastern  2.240118  0.806552
# 0d0e29faff394154a69562b4527b48b8 2019-20 Eastern  1.691567  1.286046
# 0e03e253c35d4333a1ffad2df9d38850 2019-20 Eastern  1.556977  0.906134
# 1013000201                       2019-20 Central  3.187524  1.214528
# 1013000202                       2019-20 Central  1.119655  0.550773
#
# [5 rows x 35 columns]

# %%
#Finally, define a function to change a single price in the vector $p$:
def my_prices(p0,p=pbar,j='Millet'):
    """
    Change price of jth good to p0, holding other prices fixed.
    """
    p = p.copy()
    p.loc[j] = p0
    return p

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

use = 'Beef'  # Good we want demand curve for

# Vary prices from 50% to 200% of reference.
scale = np.linspace(.5,2,20)

# Demand for Beef for household at median budget
plt.plot([result.demands(xref,my_prices(pbar[use]*s,pbar))[use] for s in scale],scale)

# Demand for Beef for household at 25% percentile
plt.plot([result.demands(xbar.quantile(0.25),my_prices(pbar[use]*s,pbar))[use] for s in scale],scale)

# Demand for Beef for household at 75% percentile
plt.plot([result.demands(xbar.quantile(0.75),my_prices(pbar[use]*s,pbar))[use] for s in scale],scale)

plt.ylabel(f"Price (relative to base of {pbar[use]:.2f})")
plt.xlabel(f"Quantities of {use} Demanded")
# Out:
# Text(0.5, 0, 'Quantities of Beef Demanded')

# %%
fig,ax = plt.subplots()

ax.plot(np.log(scale*xref),[result.expenditures(s*xref,pbar)/(s*xref) for s in scale])
ax.set_xlabel(f'log budget (relative to base of {xref:.0f}')
ax.set_ylabel(f'Expenditure share')
ax.set_title('Engel Curves')
# Out:
# Text(0.5, 1.0, 'Engel Curves')

# %% [markdown]
# ## Nutrition Analysis

# %% [markdown]
# #### Mapping Nutrient

# %%
fct.head()
# Out:
# n               Energy  Protein  Fiber  Folate  Calcium  Carbohydrate  Iron  \
# j
# Avocado           1600     20.0   70.0     810      120          85.0   6.0
# Beans (dry)       1700     98.0   60.0     500      580         325.0  30.0
# Beans (fresh)     3470    214.0  160.0    5250     1130         626.0  51.0
# Beef              2510    182.0    0.0      60       70           0.0  19.0
# Beef (roasted)    2910    264.0    0.0      70       90           0.0  27.0
#
# n               Niacin  Riboflavin  Thiamin  Vitamin A  Vitamin B-12  \
# j
# Avocado          17.38        1.30     0.67         70           0.0
# Beans (dry)       7.00        1.20     3.40          0           0.0
# Beans (fresh)    11.74        2.12     7.13          0           0.0
# Beef             31.50        1.60     0.90          0          28.9
# Beef (roasted)   37.20        2.20     0.90          0          24.7
#
# n               Vitamin B-6  Vitamin C  Zinc
# j
# Avocado                2.57        100   6.0
# Beans (dry)            2.15         10   8.0
# Beans (fresh)          4.74         63  23.0
# Beef                   3.80          0  37.0
# Beef (roasted)         3.40          0  60.0

# %%
# Create a new FCT and vector of consumption that only share rows in common:
fct0,c0 = fct.align(qhat.T,axis=0,join='inner')
print(fct0.index)
# Out:
# Index(['Beef', 'Biscuits', 'Bread', 'Cabbages', 'Chapati', 'Cooking Oil',
#        'Dodo', 'Eggs', 'Mangos', 'Millet', 'Onions', 'Oranges', 'Peas', 'Pork',
#        'Sim Sim', 'Soda', 'Sorghum', 'Sweet Bananas', 'Tomatoes', 'Waragi'],
#       dtype='object', name='j')

# %%
# The @ operator means matrix multiply
N = fct0.T@c0

N.head()  #NB: Uganda quantities are for previous 7 days
# Out:
# i       00c9353d8ebe42faabf5919b81d7fae7 0d0e29faff394154a69562b4527b48b8  \
# t                                2019-20                          2019-20
# m                                Eastern                          Eastern
# n
# Energy                      41382.922286                     29363.948017
# Protein                      1120.588446                       787.146301
# Fiber                         521.883560                       345.444659
# Folate                       9215.545435                      5818.976986
# Calcium                     14059.280271                      8941.326675
#
# i       0e03e253c35d4333a1ffad2df9d38850    1013000201    1013000202  \
# t                                2019-20       2019-20       2019-20
# m                                Eastern       Central       Central
# n
# Energy                      25931.599576  55182.478932  19425.741958
# Protein                       730.211373   1725.120449    647.051158
# Fiber                         309.850651    630.301146    219.981675
# Folate                       5385.600513  11883.440563   4652.043694
# Calcium                      8332.846305  18470.232631   6882.799755
#
# i          1013000204    1021000108    1021000109    1021000111    1021000506  \
# t             2019-20       2019-20       2019-20       2019-20       2019-20
# m             Central       Central       Central       Central       Central
# n
# Energy   70731.410003  24116.892911  55090.810216  43388.435009  35488.130738
# Protein   2139.961256    776.699349   1713.804030   1283.302577   1097.013499
# Fiber      786.351949    273.600574    621.283389    474.397454    404.429634
# Folate   13945.428455   5461.417116  11556.002092   8515.612059   7513.121200
# Calcium  22573.755196   8244.359206  16909.608475  13504.215372  11325.603389
#
# i        ... a98bebba177243668464e31f6d2bb92d  \
# t        ...                          2019-20
# m        ...                          Western
# n        ...
# Energy   ...                     99984.717159
# Protein  ...                      3005.835430
# Fiber    ...                      1485.076821
# Folate   ...                     18440.589529
# Calcium  ...                     29949.441560
#
# i       ab5cbcbe0e14402aae73b91c6917a595 acb16f9b068549d8a80a37c9d638742f  \
# t                                2019-20                          2019-20
# m                                Eastern                          Western
# n
# Energy                      38185.620468                     44246.756250
# Protein                      1019.752738                      1300.010641
# Fiber                         464.298327                       590.943296
# Folate                       7467.530995                      8330.367355
# Calcium                     11527.326738                     13389.421795
#
# i       ad9b7c4ba614444bb8004eb658693c9f bfd8253bd59c4f3199fb4b83b9cee7a6  \
# t                                2019-20                          2019-20
# m                                Eastern                          Eastern
# n
# Energy                      84834.293143                     76232.025637
# Protein                      2487.160585                      2108.613687
# Fiber                        1223.158843                      1008.794566
# Folate                      19128.963709                     15628.787484
# Calcium                     31485.682785                     24658.597580
#
# i       bfdf0d66403440ceab439b1e1c47cdea c33f6cb57d9849949e08a7350dabb829  \
# t                                2019-20                          2019-20
# m                                Eastern                          Central
# n
# Energy                      49741.149265                     27525.319894
# Protein                      1276.197667                       897.013174
# Fiber                         661.185318                       308.439082
# Folate                      10659.164193                      6145.471025
# Calcium                     15795.327748                      9497.947351
#
# i       d10a687889de469687377204195f3db0 d24fa50d02c041969a42102d8ebdadc9  \
# t                                2019-20                          2019-20
# m                                Western                          Eastern
# n
# Energy                      28360.791005                     61838.523406
# Protein                       867.911660                      1662.335939
# Fiber                         369.527140                       784.440760
# Folate                       5725.032248                     12639.622674
# Calcium                      8958.097977                     19914.927695
#
# i       e07bc322c4884559b4b8ca75c945dd3e
# t                                2019-20
# m                               Northern
# n
# Energy                      47758.390816
# Protein                      1398.781986
# Fiber                         661.781655
# Folate                       9172.740146
# Calcium                     13486.883093
#
# [5 rows x 2695 columns]

# %%
def nutrient_demand(x,p):
    c = result.demands(x,p)
    fct0,c0 = fct.align(c,axis=0,join='inner')
    N = fct0.T@c0

    N = N.loc[~N.index.duplicated()]
    
    return N

# %% [markdown]
# With this `nutrient_demand` function in hand, we can see how nutrient
#  outcomes vary with budget, given prices:

# %%
import numpy as np
import matplotlib.pyplot as plt

X = np.linspace(xref/5,xref*5,50)

UseNutrients = ['Protein','Energy','Iron','Calcium','Vitamin C']

df = pd.concat({myx:np.log(nutrient_demand(myx,pbar))[UseNutrients] for myx in X},axis=1).T
ax = df.plot()

ax.set_xlabel('log budget')
ax.set_ylabel('log nutrient')
# Out:
# Text(0, 0.5, 'log nutrient')

# %% [markdown]
# nutrition vary with one food prices

# %%
USE_GOOD = 'Beef'

scale = np.geomspace(.01,10,50)

ndf = pd.DataFrame({s:np.log(nutrient_demand(xref/2,my_prices(pbar[USE_GOOD]*s,j=USE_GOOD)))[UseNutrients] for s in scale}).T

ax = ndf.plot()

ax.set_xlabel('log price')
ax.set_ylabel('log nutrient')
# Out:
# Text(0, 0.5, 'log nutrient')

# %% [markdown]
# #### Nutrition Adequecy Ratio

# %%
yhat = result.predicted_expenditures()


use = fct.index.intersection(qhat.columns)

nutrients = qhat[use]@fct.loc[use,:]

nutrients.mean()

HH_characteristics = read_sheets(InputFiles['HH Characteristics'][0], sheet=InputFiles['HH Characteristics'][1])

if 'm' not in HH_characteristics.columns:
    HH_characteristics['m'] = 1

HH_characteristics = HH_characteristics.set_index(['i','t','m'])
HH_characteristics.columns.name = 'k' 

HH_characteristics = HH_characteristics.apply(lambda x: pd.to_numeric(x,errors='coerce'))

HH_characteristics = HH_characteristics[rdi.columns.tolist()]

hh_rdi = HH_characteristics@rdi.T

#check recommended weekly intake?
hh_rwi = hh_rdi*7
use_nutrients = nutrients.columns.intersection(hh_rwi.columns)
nutrient_ratio = (nutrients[use_nutrients]/hh_rwi[use_nutrients]).dropna()

nutrient_ratio.head()
# Out:
# n                                                   Energy   Protein  \
# i                                t       m
# 00c9353d8ebe42faabf5919b81d7fae7 2019-20 Eastern  0.501004  0.577921
# 0d0e29faff394154a69562b4527b48b8 2019-20 Eastern  0.676589  0.878511
# 0e03e253c35d4333a1ffad2df9d38850 2019-20 Eastern  0.463064  0.620928
# 1013000201                       2019-20 Central  4.927007  5.357517
# 1013000202                       2019-20 Central  0.660740  1.100427
#
# n                                                    Fiber    Folate  \
# i                                t       m
# 00c9353d8ebe42faabf5919b81d7fae7 2019-20 Eastern  0.451300  0.537350
# 0d0e29faff394154a69562b4527b48b8 2019-20 Eastern  0.568540  0.755711
# 0e03e253c35d4333a1ffad2df9d38850 2019-20 Eastern  0.395218  0.530601
# 1013000201                       2019-20 Central  4.019778  4.244086
# 1013000202                       2019-20 Central  0.534455  0.830722
#
# n                                                  Calcium  Carbohydrate  \
# i                                t       m
# 00c9353d8ebe42faabf5919b81d7fae7 2019-20 Eastern  0.247959      0.846789
# 0d0e29faff394154a69562b4527b48b8 2019-20 Eastern  0.375686      0.942265
# 0e03e253c35d4333a1ffad2df9d38850 2019-20 Eastern  0.238081      0.663910
# 1013000201                       2019-20 Central  2.198837      7.957386
# 1013000202                       2019-20 Central  0.307268      0.780477
#
# n                                                     Iron    Niacin  \
# i                                t       m
# 00c9353d8ebe42faabf5919b81d7fae7 2019-20 Eastern  0.512012  0.509419
# 0d0e29faff394154a69562b4527b48b8 2019-20 Eastern  0.703628  0.713939
# 0e03e253c35d4333a1ffad2df9d38850 2019-20 Eastern  0.513567  0.492623
# 1013000201                       2019-20 Central  7.551223  4.760480
# 1013000202                       2019-20 Central  0.755503  0.759589
#
# n                                                 Riboflavin   Thiamin  \
# i                                t       m
# 00c9353d8ebe42faabf5919b81d7fae7 2019-20 Eastern    0.664369  0.697757
# 0d0e29faff394154a69562b4527b48b8 2019-20 Eastern    0.891601  0.976694
# 0e03e253c35d4333a1ffad2df9d38850 2019-20 Eastern    0.624273  0.686263
# 1013000201                       2019-20 Central    5.668862  6.583375
# 1013000202                       2019-20 Central    1.049870  1.067948
#
# n                                                 Vitamin A  Vitamin B-12  \
# i                                t       m
# 00c9353d8ebe42faabf5919b81d7fae7 2019-20 Eastern   0.292919      0.473553
# 0d0e29faff394154a69562b4527b48b8 2019-20 Eastern   0.394745      0.817111
# 0e03e253c35d4333a1ffad2df9d38850 2019-20 Eastern   0.274814      0.574798
# 1013000201                       2019-20 Central   2.182954      4.788318
# 1013000202                       2019-20 Central   0.464351      1.062083
#
# n                                                 Vitamin B-6  Vitamin C  \
# i                                t       m
# 00c9353d8ebe42faabf5919b81d7fae7 2019-20 Eastern     0.701390   1.619605
# 0d0e29faff394154a69562b4527b48b8 2019-20 Eastern     1.118487   2.161949
# 0e03e253c35d4333a1ffad2df9d38850 2019-20 Eastern     0.764712   1.509095
# 1013000201                       2019-20 Central     5.210004   9.688701
# 1013000202                       2019-20 Central     1.105492   1.981333
#
# n                                                     Zinc
# i                                t       m
# 00c9353d8ebe42faabf5919b81d7fae7 2019-20 Eastern  0.450697
# 0d0e29faff394154a69562b4527b48b8 2019-20 Eastern  0.666980
# 0e03e253c35d4333a1ffad2df9d38850 2019-20 Eastern  0.447503
# 1013000201                       2019-20 Central  4.471159
# 1013000202                       2019-20 Central  0.769509

# %%
nutrients[use_nutrients]
# Out:
# n                                                        Energy      Protein  \
# i                                t       m
# 00c9353d8ebe42faabf5919b81d7fae7 2019-20 Eastern   41382.922286  1120.588446
# 0d0e29faff394154a69562b4527b48b8 2019-20 Eastern   29363.948017   787.146301
# 0e03e253c35d4333a1ffad2df9d38850 2019-20 Eastern   25931.599576   730.211373
# 1013000201                       2019-20 Central   55182.478932  1725.120449
# 1013000202                       2019-20 Central   19425.741958   647.051158
# ...                                                         ...          ...
# bfdf0d66403440ceab439b1e1c47cdea 2019-20 Eastern   49741.149265  1276.197667
# c33f6cb57d9849949e08a7350dabb829 2019-20 Central   27525.319894   897.013174
# d10a687889de469687377204195f3db0 2019-20 Western   28360.791005   867.911660
# d24fa50d02c041969a42102d8ebdadc9 2019-20 Eastern   61838.523406  1662.335939
# e07bc322c4884559b4b8ca75c945dd3e 2019-20 Northern  47758.390816  1398.781986
#
# n                                                       Fiber        Folate  \
# i                                t       m
# 00c9353d8ebe42faabf5919b81d7fae7 2019-20 Eastern   521.883560   9215.545435
# 0d0e29faff394154a69562b4527b48b8 2019-20 Eastern   345.444659   5818.976986
# 0e03e253c35d4333a1ffad2df9d38850 2019-20 Eastern   309.850651   5385.600513
# 1013000201                       2019-20 Central   630.301146  11883.440563
# 1013000202                       2019-20 Central   219.981675   4652.043694
# ...                                                       ...           ...
# bfdf0d66403440ceab439b1e1c47cdea 2019-20 Eastern   661.185318  10659.164193
# c33f6cb57d9849949e08a7350dabb829 2019-20 Central   308.439082   6145.471025
# d10a687889de469687377204195f3db0 2019-20 Western   369.527140   5725.032248
# d24fa50d02c041969a42102d8ebdadc9 2019-20 Eastern   784.440760  12639.622674
# e07bc322c4884559b4b8ca75c945dd3e 2019-20 Northern  661.781655   9172.740146
#
# n                                                       Calcium  Carbohydrate  \
# i                                t       m
# 00c9353d8ebe42faabf5919b81d7fae7 2019-20 Eastern   14059.280271   5394.045101
# 0d0e29faff394154a69562b4527b48b8 2019-20 Eastern    8941.326675   3429.845066
# 0e03e253c35d4333a1ffad2df9d38850 2019-20 Eastern    8332.846305   3020.788726
# 1013000201                       2019-20 Central   18470.232631   7241.221228
# 1013000202                       2019-20 Central    6882.799755   2130.703018
# ...                                                         ...           ...
# bfdf0d66403440ceab439b1e1c47cdea 2019-20 Eastern   15795.327748   6509.269624
# c33f6cb57d9849949e08a7350dabb829 2019-20 Central    9497.947351   3297.734166
# d10a687889de469687377204195f3db0 2019-20 Western    8958.097977   3467.959891
# d24fa50d02c041969a42102d8ebdadc9 2019-20 Eastern   19914.927695   8254.149726
# e07bc322c4884559b4b8ca75c945dd3e 2019-20 Northern  13486.883093   6838.299108
#
# n                                                        Iron      Niacin  \
# i                                t       m
# 00c9353d8ebe42faabf5919b81d7fae7 2019-20 Eastern   308.231460  313.801811
# 0d0e29faff394154a69562b4527b48b8 2019-20 Eastern   197.015830  209.898151
# 0e03e253c35d4333a1ffad2df9d38850 2019-20 Eastern   183.343243  193.108346
# 1013000201                       2019-20 Central   422.868498  466.527006
# 1013000202                       2019-20 Central   148.078553  159.513772
# ...                                                       ...         ...
# bfdf0d66403440ceab439b1e1c47cdea 2019-20 Eastern   336.163978  359.716636
# c33f6cb57d9849949e08a7350dabb829 2019-20 Central   209.838545  229.454723
# d10a687889de469687377204195f3db0 2019-20 Western   227.013242  229.690339
# d24fa50d02c041969a42102d8ebdadc9 2019-20 Eastern   453.501514  467.100641
# e07bc322c4884559b4b8ca75c945dd3e 2019-20 Northern  385.001057  384.754108
#
# n                                                  Riboflavin    Thiamin  \
# i                                t       m
# 00c9353d8ebe42faabf5919b81d7fae7 2019-20 Eastern    30.693852  32.236394
# 0d0e29faff394154a69562b4527b48b8 2019-20 Eastern    21.220104  22.561624
# 0e03e253c35d4333a1ffad2df9d38850 2019-20 Eastern    19.227612  20.656526
# 1013000201                       2019-20 Central    43.650238  50.691987
# 1013000202                       2019-20 Central    16.902900  17.193960
# ...                                                       ...        ...
# bfdf0d66403440ceab439b1e1c47cdea 2019-20 Eastern    36.225093  37.597164
# c33f6cb57d9849949e08a7350dabb829 2019-20 Central    22.906550  24.857466
# d10a687889de469687377204195f3db0 2019-20 Western    21.608893  24.092246
# d24fa50d02c041969a42102d8ebdadc9 2019-20 Eastern    42.735873  48.474868
# e07bc322c4884559b4b8ca75c945dd3e 2019-20 Northern   33.224887  40.786810
#
# n                                                     Vitamin A  Vitamin B-12  \
# i                                t       m
# 00c9353d8ebe42faabf5919b81d7fae7 2019-20 Eastern    9021.915034     48.728578
# 0d0e29faff394154a69562b4527b48b8 2019-20 Eastern    6079.074157     37.750517
# 0e03e253c35d4333a1ffad2df9d38850 2019-20 Eastern    5578.728377     35.005215
# 1013000201                       2019-20 Central   10696.473517     80.443745
# 1013000202                       2019-20 Central    4875.681148     35.685986
# ...                                                         ...           ...
# bfdf0d66403440ceab439b1e1c47cdea 2019-20 Eastern   10593.579375     57.021665
# c33f6cb57d9849949e08a7350dabb829 2019-20 Central    6228.807322     47.185128
# d10a687889de469687377204195f3db0 2019-20 Western    5307.616396     40.908541
# d24fa50d02c041969a42102d8ebdadc9 2019-20 Eastern   11769.117265     66.089146
# e07bc322c4884559b4b8ca75c945dd3e 2019-20 Northern   7916.036354     48.251533
#
# n                                                  Vitamin B-6    Vitamin C  \
# i                                t       m
# 00c9353d8ebe42faabf5919b81d7fae7 2019-20 Eastern     38.786860  4591.580471
# 0d0e29faff394154a69562b4527b48b8 2019-20 Eastern     28.185868  2951.060992
# 0e03e253c35d4333a1ffad2df9d38850 2019-20 Eastern     25.159035  2640.916200
# 1013000201                       2019-20 Central     54.705043  5086.567874
# 1013000202                       2019-20 Central     20.893792  1733.666187
# ...                                                        ...          ...
# bfdf0d66403440ceab439b1e1c47cdea 2019-20 Eastern     51.753271  6091.185902
# c33f6cb57d9849949e08a7350dabb829 2019-20 Central     28.904683  2545.038864
# d10a687889de469687377204195f3db0 2019-20 Western     28.940992  2164.577023
# d24fa50d02c041969a42102d8ebdadc9 2019-20 Eastern     57.679554  6667.132584
# e07bc322c4884559b4b8ca75c945dd3e 2019-20 Northern    43.020988  4262.918113
#
# n                                                        Zinc
# i                                t       m
# 00c9353d8ebe42faabf5919b81d7fae7 2019-20 Eastern   170.363394
# 0d0e29faff394154a69562b4527b48b8 2019-20 Eastern   116.721457
# 0e03e253c35d4333a1ffad2df9d38850 2019-20 Eastern   109.638280
# 1013000201                       2019-20 Central   250.384882
# 1013000202                       2019-20 Central    96.958157
# ...                                                       ...
# bfdf0d66403440ceab439b1e1c47cdea 2019-20 Eastern   192.141159
# c33f6cb57d9849949e08a7350dabb829 2019-20 Central   132.577920
# d10a687889de469687377204195f3db0 2019-20 Western   136.739029
# d24fa50d02c041969a42102d8ebdadc9 2019-20 Eastern   250.406268
# e07bc322c4884559b4b8ca75c945dd3e 2019-20 Northern  205.309174
#
# [2695 rows x 15 columns]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

def plot_nutrition_table(ratio_table, nutrition):
    """
    This function is designed to create a histogram displaying the distribution of nutrition adequacy 
    for households in the Panama Country dataset.

    Parameters:
    - ratio_table (DataFrame): The DataFrame containing the nutrient ratios.
    - nutrition (string): The name of the nutrient column to plot.

    Returns:
    - A histogram for the specified nutrient adequacy among households.
    """
    fig, ax = plt.subplots(figsize=(10, 6))
    ratio_table[nutrition].hist(ax=ax, bins=30, color = 'g')  # Use ax=ax to plot on the created axes
    plt.title(f'Households [{nutrition}] Adequacy Histogram in Uganda')
    plt.xlabel(f'[{nutrition}] Adequacy Ratio')
    plt.ylabel('Count of Households')
    plt.show()


print("Please choose from the following:\n'Energy', 'Protein', 'Fiber', 'Folate', 'Calcium', 'Carbohydrate','Iron', 'Niacin', 'Riboflavin', 'Thiamin', 'Vitamin A', 'Vitamin B-12', 'Vitamin B-6', 'Vitamin C', 'Zinc']")
print("\n")  
nutrition_input = input('Please input the nutrition you would like to visualize (No quotation mark required): ')
plot_nutrition_table(nutrient_ratio, nutrition_input)
# Out:
# Please choose from the following:
# 'Energy', 'Protein', 'Fiber', 'Folate', 'Calcium', 'Carbohydrate','Iron', 'Niacin', 'Riboflavin', 'Thiamin', 'Vitamin A', 'Vitamin B-12', 'Vitamin B-6', 'Vitamin C', 'Zinc']
# Please input the nutrition you would like to visualize (No quotation mark required):  Protein

# %% [markdown]
# ## Policy Implementation

# %%
#Increasing wages
# Calculate the 25th percentile of xbar
xbar_25th_percentile = xbar.quantile(0.25)

# %%
# Increase the budget by 10%
xbar_increase = xbar.apply(lambda x: x + 10246 if x < xbar_25th_percentile else x)

# Assuming we need to recalculate nutrient intake with the increased budget
# We need the price vector pbar, assuming it's defined elsewhere in your notebook
nutrients_increased = pd.concat({myx: nutrient_demand(myx, pbar)[UseNutrients] for myx in xbar_increase}, axis=1).T

# Assuming the rest of the code uses nutrients dataframe directly
# We replace the old nutrients dataframe with the new one
nutrients2 = nutrients_increased
nutrients_reset = nutrients.reset_index()
nutrients2_reset = nutrients2.reset_index()

# Define the common columns you wish to replace
common_columns = ['Protein', 'Energy', 'Iron', 'Calcium', 'Vitamin C']

# Replace columns in nutrients_reset with those from nutrients2_reset
nutrients_reset.loc[:, common_columns] = nutrients2_reset[common_columns]

# Optional: Reset index if you need the DataFrame in the original form
nutrients_final = nutrients_reset.reset_index()

nutrients_final = nutrients_final.set_index(['i', 't', 'm'])

# Continue with the previous operations
HH_characteristics = read_sheets(InputFiles['HH Characteristics'][0], sheet=InputFiles['HH Characteristics'][1])

if 'm' not in HH_characteristics.columns:
    HH_characteristics['m'] = 1

HH_characteristics = HH_characteristics.set_index(['i','t','m'])
HH_characteristics.columns.name = 'k' 

HH_characteristics = HH_characteristics.apply(lambda x: pd.to_numeric(x, errors='coerce'))

# Assuming rdi is defined elsewhere
HH_characteristics = HH_characteristics[rdi.columns.tolist()]
hh_rdi = HH_characteristics @ rdi.T
hh_rwi = hh_rdi * 7

# Recalculate the nutrient ratio with the updated nutrient intake data
use_nutrients = nutrients_final.columns.intersection(hh_rwi.columns)
nutrient_ratio_inc = (nutrients_final[use_nutrients] / hh_rwi[use_nutrients]).dropna()

# Display the updated ratios
nutrient_ratio_inc.head()
# Out:
# n                                                   Energy   Protein  \
# i                                t       m
# 00c9353d8ebe42faabf5919b81d7fae7 2019-20 Eastern  0.603272  0.756072
# 0d0e29faff394154a69562b4527b48b8 2019-20 Eastern  0.826111  1.188204
# 0e03e253c35d4333a1ffad2df9d38850 2019-20 Eastern  0.598767  0.848282
# 1013000201                       2019-20 Central  5.985851  6.075718
# 1013000202                       2019-20 Central  0.965792  1.443557
#
# n                                                    Fiber    Folate  \
# i                                t       m
# 00c9353d8ebe42faabf5919b81d7fae7 2019-20 Eastern  0.451300  0.537350
# 0d0e29faff394154a69562b4527b48b8 2019-20 Eastern  0.568540  0.755711
# 0e03e253c35d4333a1ffad2df9d38850 2019-20 Eastern  0.395218  0.530601
# 1013000201                       2019-20 Central  4.019778  4.244086
# 1013000202                       2019-20 Central  0.534455  0.830722
#
# n                                                  Calcium  Carbohydrate  \
# i                                t       m
# 00c9353d8ebe42faabf5919b81d7fae7 2019-20 Eastern  0.291539      0.846789
# 0d0e29faff394154a69562b4527b48b8 2019-20 Eastern  0.498752      0.942265
# 0e03e253c35d4333a1ffad2df9d38850 2019-20 Eastern  0.317067      0.663910
# 1013000201                       2019-20 Central  2.652122      7.957386
# 1013000202                       2019-20 Central  0.419175      0.780477
#
# n                                                     Iron    Niacin  \
# i                                t       m
# 00c9353d8ebe42faabf5919b81d7fae7 2019-20 Eastern  0.667125  0.509419
# 0d0e29faff394154a69562b4527b48b8 2019-20 Eastern  1.012274  0.713939
# 0e03e253c35d4333a1ffad2df9d38850 2019-20 Eastern  0.739609  0.492623
# 1013000201                       2019-20 Central  9.815192  4.760480
# 1013000202                       2019-20 Central  1.129780  0.759589
#
# n                                                 Riboflavin   Thiamin  \
# i                                t       m
# 00c9353d8ebe42faabf5919b81d7fae7 2019-20 Eastern    0.664369  0.697757
# 0d0e29faff394154a69562b4527b48b8 2019-20 Eastern    0.891601  0.976694
# 0e03e253c35d4333a1ffad2df9d38850 2019-20 Eastern    0.624273  0.686263
# 1013000201                       2019-20 Central    5.668862  6.583375
# 1013000202                       2019-20 Central    1.049870  1.067948
#
# n                                                 Vitamin A  Vitamin B-12  \
# i                                t       m
# 00c9353d8ebe42faabf5919b81d7fae7 2019-20 Eastern   0.292919      0.473553
# 0d0e29faff394154a69562b4527b48b8 2019-20 Eastern   0.394745      0.817111
# 0e03e253c35d4333a1ffad2df9d38850 2019-20 Eastern   0.274814      0.574798
# 1013000201                       2019-20 Central   2.182954      4.788318
# 1013000202                       2019-20 Central   0.464351      1.062083
#
# n                                                 Vitamin B-6  Vitamin C  \
# i                                t       m
# 00c9353d8ebe42faabf5919b81d7fae7 2019-20 Eastern     0.701390   1.145995
# 0d0e29faff394154a69562b4527b48b8 2019-20 Eastern     1.118487   1.683102
# 0e03e253c35d4333a1ffad2df9d38850 2019-20 Eastern     0.764712   1.223845
# 1013000201                       2019-20 Central     5.210004   8.474839
# 1013000202                       2019-20 Central     1.105492   2.057171
#
# n                                                     Zinc
# i                                t       m
# 00c9353d8ebe42faabf5919b81d7fae7 2019-20 Eastern  0.450697
# 0d0e29faff394154a69562b4527b48b8 2019-20 Eastern  0.666980
# 0e03e253c35d4333a1ffad2df9d38850 2019-20 Eastern  0.447503
# 1013000201                       2019-20 Central  4.471159
# 1013000202                       2019-20 Central  0.769509

# %%
plot_nutrition_table(nutrient_ratio_inc, nutrition_input)

# %%
fig, ax = plt.subplots(figsize=(10, 8))
ax.hist(nutrient_ratio_inc[nutrition_input], color='b', bins = 30, alpha=0.3, label= "increase", density = True)
ax.hist(nutrient_ratio[nutrition_input], color='g', bins = 30, alpha=0.3, label= "no increase", density = True)
ax.legend()
plt.xlabel(f'[{nutrition_input}] Adequacy Ratio')
plt.ylabel('Count of Households')
plt.show()
plt.show()

# %%
# # Replace the specified columns in 'nutrients' with those from 'nutrients2'
# # # nutrients.loc[:, common_columns] = nutrients2[common_columns]
# # nutrients_copy[['Energy']] = nutrients2[['Energy']]
# # nutrients_copy[['Energy']]
# nutrients2 = nutrients2.reset_index(drop=True)
# nutrients_copy[['Energy']]= nutrients2[['Energy']]
# nutrients_copy.reset_index()[['Energy']] = nutrients2[['Energy']]
# nutrients_copy[
nutrients_reset = nutrients.reset_index()
nutrients2_reset = nutrients2.reset_index()

# nutrients_reset.set_index(['n'], inplace=True)
# nutrients2_reset.set_index(['n'], inplace=True)

# Define the common columns you wish to replace
common_columns = ['Protein', 'Energy', 'Iron', 'Calcium', 'Vitamin C']

# Replace columns in nutrients_reset with those from nutrients2_reset
nutrients_reset.loc[:, common_columns] = nutrients2_reset[common_columns]

# Optional: Reset index if you need the DataFrame in the original form
nutrients_final = nutrients_reset.reset_index()

nutrients_final.set_index(['i', 't', 'm'])
# Out:
# n                                                  index        Energy  \
# i                                t       m
# 00c9353d8ebe42faabf5919b81d7fae7 2019-20 Eastern       0  55154.457912
# 0d0e29faff394154a69562b4527b48b8 2019-20 Eastern       1  35547.857625
# 0e03e253c35d4333a1ffad2df9d38850 2019-20 Eastern       2  32995.055030
# 1013000201                       2019-20 Central       3  74159.442344
# 1013000202                       2019-20 Central       4  27353.004848
# ...                                                  ...           ...
# bfdf0d66403440ceab439b1e1c47cdea 2019-20 Eastern    2690  69942.044658
# c33f6cb57d9849949e08a7350dabb829 2019-20 Central    2691  36819.226383
# d10a687889de469687377204195f3db0 2019-20 Western    2692  35449.982450
# d24fa50d02c041969a42102d8ebdadc9 2019-20 Eastern    2693  84343.708544
# e07bc322c4884559b4b8ca75c945dd3e 2019-20 Northern   2694  55960.045374
#
# n                                                      Protein       Fiber  \
# i                                t       m
# 00c9353d8ebe42faabf5919b81d7fae7 2019-20 Eastern   1618.109076  521.883560
# 0d0e29faff394154a69562b4527b48b8 2019-20 Eastern   1055.821000  345.444659
# 0e03e253c35d4333a1ffad2df9d38850 2019-20 Eastern    982.088853  309.850651
# 1013000201                       2019-20 Central   2158.204231  630.301146
# 1013000202                       2019-20 Central    818.569684  219.981675
# ...                                                        ...         ...
# bfdf0d66403440ceab439b1e1c47cdea 2019-20 Eastern   2038.683770  661.185318
# c33f6cb57d9849949e08a7350dabb829 2019-20 Central   1092.488844  308.439082
# d10a687889de469687377204195f3db0 2019-20 Western   1052.996740  369.527140
# d24fa50d02c041969a42102d8ebdadc9 2019-20 Eastern   2446.156807  784.440760
# e07bc322c4884559b4b8ca75c945dd3e 2019-20 Northern  1641.087572  661.781655
#
# n                                                        Folate       Calcium  \
# i                                t       m
# 00c9353d8ebe42faabf5919b81d7fae7 2019-20 Eastern    9215.545435  18307.551576
# 0d0e29faff394154a69562b4527b48b8 2019-20 Eastern    5818.976986  11768.644026
# 0e03e253c35d4333a1ffad2df9d38850 2019-20 Eastern    5385.600513  10919.037256
# 1013000201                       2019-20 Central   11883.440563  24655.851587
# 1013000202                       2019-20 Central    4652.043694   9043.707755
# ...                                                         ...           ...
# bfdf0d66403440ceab439b1e1c47cdea 2019-20 Eastern   10659.164193  23246.831949
# c33f6cb57d9849949e08a7350dabb829 2019-20 Central    6145.471025  12191.982817
# d10a687889de469687377204195f3db0 2019-20 Western    5725.032248  11736.059190
# d24fa50d02c041969a42102d8ebdadc9 2019-20 Eastern   12639.622674  28058.337573
# e07bc322c4884559b4b8ca75c945dd3e 2019-20 Northern   9172.740146  18576.538780
#
# n                                                  Carbohydrate        Iron  \
# i                                t       m
# 00c9353d8ebe42faabf5919b81d7fae7 2019-20 Eastern    5394.045101  447.152038
# 0d0e29faff394154a69562b4527b48b8 2019-20 Eastern    3429.845066  280.881893
# 0e03e253c35d4333a1ffad2df9d38850 2019-20 Eastern    3020.788726  259.575580
# 1013000201                       2019-20 Central    7241.221228  611.482506
# 1013000202                       2019-20 Central    2130.703018  212.856441
# ...                                                         ...         ...
# bfdf0d66403440ceab439b1e1c47cdea 2019-20 Eastern    6509.269624  574.809488
# c33f6cb57d9849949e08a7350dabb829 2019-20 Central    3297.734166  291.527980
# d10a687889de469687377204195f3db0 2019-20 Western    3467.959891  280.063251
# d24fa50d02c041969a42102d8ebdadc9 2019-20 Eastern    8254.149726  700.445932
# e07bc322c4884559b4b8ca75c945dd3e 2019-20 Northern   6838.299108  454.064356
#
# n                                                      Niacin  Riboflavin  \
# i                                t       m
# 00c9353d8ebe42faabf5919b81d7fae7 2019-20 Eastern   313.801811   30.693852
# 0d0e29faff394154a69562b4527b48b8 2019-20 Eastern   209.898151   21.220104
# 0e03e253c35d4333a1ffad2df9d38850 2019-20 Eastern   193.108346   19.227612
# 1013000201                       2019-20 Central   466.527006   43.650238
# 1013000202                       2019-20 Central   159.513772   16.902900
# ...                                                       ...         ...
# bfdf0d66403440ceab439b1e1c47cdea 2019-20 Eastern   359.716636   36.225093
# c33f6cb57d9849949e08a7350dabb829 2019-20 Central   229.454723   22.906550
# d10a687889de469687377204195f3db0 2019-20 Western   229.690339   21.608893
# d24fa50d02c041969a42102d8ebdadc9 2019-20 Eastern   467.100641   42.735873
# e07bc322c4884559b4b8ca75c945dd3e 2019-20 Northern  384.754108   33.224887
#
# n                                                    Thiamin     Vitamin A  \
# i                                t       m
# 00c9353d8ebe42faabf5919b81d7fae7 2019-20 Eastern   32.236394   9021.915034
# 0d0e29faff394154a69562b4527b48b8 2019-20 Eastern   22.561624   6079.074157
# 0e03e253c35d4333a1ffad2df9d38850 2019-20 Eastern   20.656526   5578.728377
# 1013000201                       2019-20 Central   50.691987  10696.473517
# 1013000202                       2019-20 Central   17.193960   4875.681148
# ...                                                      ...           ...
# bfdf0d66403440ceab439b1e1c47cdea 2019-20 Eastern   37.597164  10593.579375
# c33f6cb57d9849949e08a7350dabb829 2019-20 Central   24.857466   6228.807322
# d10a687889de469687377204195f3db0 2019-20 Western   24.092246   5307.616396
# d24fa50d02c041969a42102d8ebdadc9 2019-20 Eastern   48.474868  11769.117265
# e07bc322c4884559b4b8ca75c945dd3e 2019-20 Northern  40.786810   7916.036354
#
# n                                                  Vitamin B-12  Vitamin B-6  \
# i                                t       m
# 00c9353d8ebe42faabf5919b81d7fae7 2019-20 Eastern      48.728578    38.786860
# 0d0e29faff394154a69562b4527b48b8 2019-20 Eastern      37.750517    28.185868
# 0e03e253c35d4333a1ffad2df9d38850 2019-20 Eastern      35.005215    25.159035
# 1013000201                       2019-20 Central      80.443745    54.705043
# 1013000202                       2019-20 Central      35.685986    20.893792
# ...                                                         ...          ...
# bfdf0d66403440ceab439b1e1c47cdea 2019-20 Eastern      57.021665    51.753271
# c33f6cb57d9849949e08a7350dabb829 2019-20 Central      47.185128    28.904683
# d10a687889de469687377204195f3db0 2019-20 Western      40.908541    28.940992
# d24fa50d02c041969a42102d8ebdadc9 2019-20 Eastern      66.089146    57.679554
# e07bc322c4884559b4b8ca75c945dd3e 2019-20 Northern     48.251533    43.020988
#
# n                                                    Vitamin C        Zinc
# i                                t       m
# 00c9353d8ebe42faabf5919b81d7fae7 2019-20 Eastern   3617.120370  170.363394
# 0d0e29faff394154a69562b4527b48b8 2019-20 Eastern   2276.919296  116.721457
# 0e03e253c35d4333a1ffad2df9d38850 2019-20 Eastern   2105.901889  109.638280
# 1013000201                       2019-20 Central   4953.634187  250.384882
# 1013000202                       2019-20 Central   1731.235078   96.958157
# ...                                                        ...         ...
# bfdf0d66403440ceab439b1e1c47cdea 2019-20 Eastern   4654.290189  192.141159
# c33f6cb57d9849949e08a7350dabb829 2019-20 Central   2362.419277  132.577920
# d10a687889de469687377204195f3db0 2019-20 Western   2270.346083  136.739029
# d24fa50d02c041969a42102d8ebdadc9 2019-20 Eastern   5682.354216  250.406268
# e07bc322c4884559b4b8ca75c945dd3e 2019-20 Northern  3673.089214  205.309174
#
# [2695 rows x 16 columns]
